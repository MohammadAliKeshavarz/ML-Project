# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! git clone https://github.com/fra31/auto-attack.git
# Out:
# Cloning into 'auto-attack'...
# remote: Enumerating objects: 672, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 672 (delta 162), reused 159 (delta 141), pack-reused 463
# Receiving objects: 100% (672/672), 40.63 MiB | 12.73 MiB/s, done.
# Resolving deltas: 100% (413/413), done.

# %%
# !pip install git+https://github.com/fra31/auto-attack
# Out:
# Collecting git+https://github.com/fra31/auto-attack
#   Cloning https://github.com/fra31/auto-attack to /tmp/pip-req-build-_dakvmbl
#   Running command git clone --filter=blob:none --quiet https://github.com/fra31/auto-attack /tmp/pip-req-build-_dakvmbl
#   Resolved https://github.com/fra31/auto-attack to commit a39220048b3c9f2cca9a4d3a54604793c68eca7e
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: autoattack
#   Building wheel for autoattack (setup.py) ... done
#   Created wheel for autoattack: filename=autoattack-0.1-py3-none-any.whl size=36229 sha256=8db46cb539184e5b9c9207b0e812cc3e484a29bd2bfadb4784fd29f87e2200ab
#   Stored in directory: /tmp/pip-ephem-wheel-cache-25qnakfd/wheels/b7/17/95/4b16fafe1b84fdabd247eb5f01b41165bd98d4c82d64ab93d2
# Successfully built autoattack
# Installing collected packages: autoattack
# Successfully installed autoattack-0.1

# %%
# Copy Files
# !cp /content/drive/MyDrive/ML-Project/Test1.rar /content

# %%
! unrar x /content/Test1.rar
# Out:
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from /content/Test1.rar
#
#   OK
#   OK
# All OK

# %%
# !cp -r /content/resnet.py /content/auto-attack/autoattack/examples

# %%
# %%shell
# cat > /content/auto-attack/autoattack/examples/eval.py << EOF
#
# import os
# import argparse
# from pathlib import Path
# import warnings
#
# import torch
# import torch.nn as nn
# import torchvision.datasets as datasets
# import torch.utils.data as data
# import torchvision.transforms as transforms
#
# import sys
# sys.path.insert(0,'..')
# from resnet import ResNet34
#
# if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--data_dir', type=str, default='./data')
#     parser.add_argument('--norm', type=str, default='L2')
#     parser.add_argument('--epsilon', type=float, default=0.3)
#     #///////////////////////////////////////////////////////////////
#     parser.add_argument('--model', type=str, default='/content/ckpt.pth')
#     #///////////////////////////////////////////////////////////////
#     parser.add_argument('--n_ex', type=int, default=1000)
#     parser.add_argument('--individual', action='store_true')
#     parser.add_argument('--save_dir', type=str, default='./results')
#     parser.add_argument('--batch_size', type=int, default=500)
#     parser.add_argument('--log_path', type=str, default='./log_file.txt')
#     parser.add_argument('--version', type=str, default='standard')
#     parser.add_argument('--state-path', type=Path, default=None)
#
#     args = parser.parse_args()
#
#     # load model
#     model = ResNet34()
#     #//////////////////////////////////////////////
#     model = nn.DataParallel(model)
#     loaded = torch.load(args.model)
#     model.load_state_dict(loaded['net'])
#     #//////////////////////////////////////////////
#     model.cuda()
#     model.eval()
#
#     # load data
#     transform_list = [transforms.ToTensor(), transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))]
#     transform_chain = transforms.Compose(transform_list)
#     item = datasets.CIFAR10(root=args.data_dir, train=False, transform=transform_chain, download=True)
#     test_loader = data.DataLoader(item, batch_size=1000, shuffle=False, num_workers=0)
#
#     # create save dir
#     if not os.path.exists(args.save_dir):
#         os.makedirs(args.save_dir)
#
#     # load attack
#     from autoattack import AutoAttack
#     adversary = AutoAttack(model, norm=args.norm, eps=args.epsilon, log_path=args.log_path,
#         version=args.version)
#
#     l = [x for (x, y) in test_loader]
#     x_test = torch.cat(l, 0)
#     l = [y for (x, y) in test_loader]
#     y_test = torch.cat(l, 0)
#
#     # example of custom version
#     if args.version == 'custom':
#         adversary.attacks_to_run = ['apgd-ce', 'fab']
#         adversary.apgd.n_restarts = 2
#         adversary.fab.n_restarts = 2
#
#     # run attack and save images
#     with torch.no_grad():
#         if not args.individual:
#             adv_complete = adversary.run_standard_evaluation(x_test[:args.n_ex], y_test[:args.n_ex],
#                 bs=args.batch_size, state_path=args.state_path)
#
#             torch.save({'adv_complete': adv_complete}, '{}/{}_{}_1_{}_eps_{:.5f}.pth'.format(
#                 args.save_dir, 'aa', args.version, adv_complete.shape[0], args.epsilon))
#
#         else:
#             # individual version, each attack is run on all test points
#             adv_complete = adversary.run_standard_evaluation_individual(x_test[:args.n_ex],
#                 y_test[:args.n_ex], bs=args.batch_size)
#
#             torch.save(adv_complete, '{}/{}_{}_individual_1_{}_eps_{:.5f}_plus_{}_cheap_{}.pth'.format(
#                 args.save_dir, 'aa', args.version, args.n_ex, args.epsilon))
# Out:
# /bin/bash: line 86: warning: here-document at line 0 delimited by end-of-file (wanted `EOF')

# %% [markdown]
# #AA-L2

# %% [markdown]
# ##eps = 0.3

# %%
epsilon = 0.3
norm = 'L2'
! python /content/auto-attack/autoattack/examples/eval.py --epsilon $epsilon --norm $norm
print("Finish!")
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100% 170498071/170498071 [00:05<00:00, 29274447.50it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# setting parameters for standard version
# using standard version including apgd-ce, apgd-t, fab-t, square.
# initial accuracy: 95.70%
# apgd-ce - 1/2 - 198 out of 500 successfully perturbed
# apgd-ce - 2/2 - 192 out of 457 successfully perturbed
# robust accuracy after APGD-CE: 56.70% (total time 90.3 s)
# apgd-t - 1/2 - 6 out of 500 successfully perturbed
# apgd-t - 2/2 - 0 out of 67 successfully perturbed
# robust accuracy after APGD-T: 56.10% (total time 584.8 s)
# fab-t - 1/2 - 0 out of 500 successfully perturbed
# fab-t - 2/2 - 0 out of 61 successfully perturbed
# robust accuracy after FAB-T: 56.10% (total time 1488.5 s)
# square - 1/2 - 6 out of 500 successfully perturbed
# square - 2/2 - 0 out of 61 successfully perturbed
# robust accuracy after SQUARE: 55.50% (total time 2762.3 s)
# Warning: Square Attack has decreased the robust accuracy of 0.60%. This might indicate that the robustness evaluation using AutoAttack is unreliable. Consider running Square Attack with more iterations and restarts or an adaptive attack. See flags_doc.md for details.
# max L2 perturbation: 110.26619, nan in tensor: 0, max: 2.75373, min: -2.42907
# robust accuracy: 55.50%
# Finish!

# %% [markdown]
# ##eps = 0.4

# %%
epsilon = 0.4
norm = 'L2'
! python /content/auto-attack/autoattack/examples/eval.py --epsilon $epsilon --norm $norm
print("Finish!")
# Out:
# Files already downloaded and verified
# setting parameters for standard version
# using standard version including apgd-ce, apgd-t, fab-t, square.
# initial accuracy: 95.70%
# apgd-ce - 1/2 - 198 out of 500 successfully perturbed
# apgd-ce - 2/2 - 192 out of 457 successfully perturbed
# robust accuracy after APGD-CE: 56.70% (total time 92.1 s)
# apgd-t - 1/2 - 10 out of 500 successfully perturbed
# apgd-t - 2/2 - 0 out of 67 successfully perturbed
# robust accuracy after APGD-T: 55.70% (total time 581.7 s)
# fab-t - 1/2 - 0 out of 500 successfully perturbed
# fab-t - 2/2 - 0 out of 57 successfully perturbed
# robust accuracy after FAB-T: 55.70% (total time 1481.3 s)
# square - 1/2 - 6 out of 500 successfully perturbed
# square - 2/2 - 0 out of 57 successfully perturbed
# robust accuracy after SQUARE: 55.10% (total time 2751.6 s)
# Warning: Square Attack has decreased the robust accuracy of 0.60%. This might indicate that the robustness evaluation using AutoAttack is unreliable. Consider running Square Attack with more iterations and restarts or an adaptive attack. See flags_doc.md for details.
# max L2 perturbation: 110.26619, nan in tensor: 0, max: 2.75373, min: -2.42907
# robust accuracy: 55.10%
# Finish!

# %% [markdown]
# ##eps = 0.5

# %%
epsilon = 0.5
norm = 'L2'
! python /content/auto-attack/autoattack/examples/eval.py --epsilon $epsilon --norm $norm
print("Finish!")
# Out:
# Files already downloaded and verified
# setting parameters for standard version
# using standard version including apgd-ce, apgd-t, fab-t, square.
# initial accuracy: 95.70%
# apgd-ce - 1/2 - 199 out of 500 successfully perturbed
# apgd-ce - 2/2 - 192 out of 457 successfully perturbed
# robust accuracy after APGD-CE: 56.60% (total time 92.1 s)
# apgd-t - 1/2 - 15 out of 500 successfully perturbed
# apgd-t - 2/2 - 0 out of 66 successfully perturbed
# robust accuracy after APGD-T: 55.10% (total time 581.2 s)
# fab-t - 1/2 - 0 out of 500 successfully perturbed
# fab-t - 2/2 - 0 out of 51 successfully perturbed
# robust accuracy after FAB-T: 55.10% (total time 1476.3 s)
# square - 1/2 - 11 out of 500 successfully perturbed
# square - 2/2 - 0 out of 51 successfully perturbed
# robust accuracy after SQUARE: 54.00% (total time 2732.0 s)
# Warning: Square Attack has decreased the robust accuracy of 1.10%. This might indicate that the robustness evaluation using AutoAttack is unreliable. Consider running Square Attack with more iterations and restarts or an adaptive attack. See flags_doc.md for details.
# max L2 perturbation: 110.26619, nan in tensor: 0, max: 2.75373, min: -2.42907
# robust accuracy: 54.00%
# Finish!

# %% [markdown]
# #AA-Linf

# %% [markdown]
# ##eps = 4/255

# %%
epsilon = 4/255
norm = 'Linf'
! python /content/auto-attack/autoattack/examples/eval.py --epsilon $epsilon --norm $norm
print("Finish!")
# Out:
# Files already downloaded and verified
# setting parameters for standard version
# using standard version including apgd-ce, apgd-t, fab-t, square.
# initial accuracy: 95.70%
# apgd-ce - 1/2 - 352 out of 500 successfully perturbed
# apgd-ce - 2/2 - 306 out of 457 successfully perturbed
# robust accuracy after APGD-CE: 29.90% (total time 92.0 s)
# apgd-t - 1/1 - 0 out of 299 successfully perturbed
# robust accuracy after APGD-T: 29.90% (total time 354.0 s)
# fab-t - 1/1 - 0 out of 299 successfully perturbed
# robust accuracy after FAB-T: 29.90% (total time 843.4 s)
# square - 1/1 - 0 out of 299 successfully perturbed
# robust accuracy after SQUARE: 29.90% (total time 1516.3 s)
# max Linf perturbation: 2.42907, nan in tensor: 0, max: 2.75373, min: -2.42907
# robust accuracy: 29.90%
# Finish!

# %% [markdown]
# ##eps = 6/255

# %%
epsilon = 6/255
norm = 'Linf'
! python /content/auto-attack/autoattack/examples/eval.py --epsilon $epsilon --norm $norm
print("Finish!")
# Out:
# Files already downloaded and verified
# setting parameters for standard version
# using standard version including apgd-ce, apgd-t, fab-t, square.
# initial accuracy: 95.70%
# apgd-ce - 1/2 - 393 out of 500 successfully perturbed
# apgd-ce - 2/2 - 369 out of 457 successfully perturbed
# robust accuracy after APGD-CE: 19.50% (total time 92.0 s)
# apgd-t - 1/1 - 6 out of 195 successfully perturbed
# robust accuracy after APGD-T: 18.90% (total time 262.0 s)
# fab-t - 1/1 - 0 out of 189 successfully perturbed
# robust accuracy after FAB-T: 18.90% (total time 575.0 s)
# square - 1/1 - 0 out of 189 successfully perturbed
# robust accuracy after SQUARE: 18.90% (total time 1000.2 s)
# max Linf perturbation: 2.42907, nan in tensor: 0, max: 2.75373, min: -2.42907
# robust accuracy: 18.90%
# Finish!

# %% [markdown]
# ##eps = 8/255

# %%
epsilon = 8/255
norm = 'Linf'
! python /content/auto-attack/autoattack/examples/eval.py --epsilon $epsilon --norm $norm
print("Finish!")
# Out:
# Files already downloaded and verified
# setting parameters for standard version
# using standard version including apgd-ce, apgd-t, fab-t, square.
# initial accuracy: 95.70%
# apgd-ce - 1/2 - 427 out of 500 successfully perturbed
# apgd-ce - 2/2 - 395 out of 457 successfully perturbed
# robust accuracy after APGD-CE: 13.50% (total time 92.0 s)
# apgd-t - 1/1 - 4 out of 135 successfully perturbed
# robust accuracy after APGD-T: 13.10% (total time 216.0 s)
# fab-t - 1/1 - 0 out of 131 successfully perturbed
# robust accuracy after FAB-T: 13.10% (total time 445.1 s)
# square - 1/1 - 0 out of 131 successfully perturbed
# robust accuracy after SQUARE: 13.10% (total time 758.7 s)
# max Linf perturbation: 2.42907, nan in tensor: 0, max: 2.75373, min: -2.42907
# robust accuracy: 13.10%
# Finish!
