# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Copy Files
# !cp /content/drive/MyDrive/ML-Project/Test1.rar /content

# %%
! unrar x /content/Test1.rar
# Out:
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from /content/Test1.rar
#
#   OK
#   OK
# All OK

# %%
! git clone https://github.com/alirezaabdollahpour/ML_Graduate_Project_TA.git
# Out:
# Cloning into 'ML_Graduate_Project_TA'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 28 (delta 7), reused 18 (delta 5), pack-reused 0
# Unpacking objects: 100% (28/28), 8.91 KiB | 1.48 MiB/s, done.

# %%
# !cp -r /content/resnet.py /content/ML_Graduate_Project_TA/Phase_1

# %%
! mkdir results-cifar10

# %%
pip install git+https://github.com/RobustBench/robustbench.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/RobustBench/robustbench.git to /tmp/pip-req-build-yknngvjy
#   Running command git clone --filter=blob:none --quiet https://github.com/RobustBench/robustbench.git /tmp/pip-req-build-yknngvjy
#   Resolved https://github.com/RobustBench/robustbench.git to commit ec26a6cd0b0812135270c3659caabcab80701b15
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/fra31/auto-attack.git (to revision a39220048b3c9f2cca9a4d3a54604793c68eca7e) to /tmp/pip-install-5g1fqrll/autoattack_e9b0cc0a3d5b4375ab681ce53869a9e2
#   Running command git clone --filter=blob:none --quiet https://github.com/fra31/auto-attack.git /tmp/pip-install-5g1fqrll/autoattack_e9b0cc0a3d5b4375ab681ce53869a9e2
#   Running command git rev-parse -q --verify 'sha^a39220048b3c9f2cca9a4d3a54604793c68eca7e'
# ...

# %%
! python /content/ML_Graduate_Project_TA/Phase_1/test.py
# Out:
# device is :cuda:0
# ...
# 100% 170498071/170498071 [00:01<00:00, 99520149.11it/s]
# Extracting data/torchvision/cifar-10-python.tar.gz to data/torchvision
# Accuracy of ResNet34 model: 0.97

# %%
# !cp -r ML_Graduate_Project_TA "drive/MyDrive/"
